# %% [markdown]
# # 02 Обучение на реальных строительных данных
# Запуск основного train-скрипта и чтение артефактов.

# %%
# Команда обучения (выполняется из корня репозитория)
# !python -m src.train_tabular --data data/raw/real_construction_data.csv --target SalePrice --model xgboost --tune --n-iter 30 --cv-folds 5 --save-dir outputs/real_data

# %%
# Читаем метрики после обучения
import json
from pathlib import Path
metrics_path = Path("../outputs/real_data/metrics.json")
if metrics_path.exists():
    print(json.loads(metrics_path.read_text(encoding="utf-8")))
else:
    print("Сначала запусти обучение, чтобы получить metrics.json")
